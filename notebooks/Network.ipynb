# %%
# %load_ext autoreload
# %autoreload 2
import os
os.chdir('..')

# %% [markdown]
# <h1> Networkx Experiments

# %%
# Getting familiar with Networkx

# %%
H=nx.path_graph(10)
G.add_nodes_from(H)

# %%
G.clear()

# %%
G.add_edges_from([(1,2),(1,3)])
G.add_node(1)
G.add_edge(1,2)
G.add_node("spam")       # adds node "spam"
G.add_nodes_from("spam") # adds 4 nodes: 's', 'p', 'a', 'm'

# %%
G.add_edge('spam', 1)

# %%
G.nodes
# Out:
# NodeView((1, 2, 3, 'spam', 's', 'p', 'a', 'm'))

# %%
list(G.neighbors(1))
# Out:
# [2, 3, 'spam']

# %%
G.remove_nodes_from('spam')

# %%
G.edges
# Out:
# EdgeView([(1, 2), (1, 3), (1, 'spam')])

# %%
>>> H=nx.DiGraph(G)   # create a DiGraph using the connections from G

# %%
F = nx.convert_node_labels_to_integers(G)

# %%
F.nodes[0]
# Out:
# {}

# %%
F.nodes[0]['color'] = 0

# %%
F.nodes[0]
# Out:
# {'color': 0}

# %%
G[1][2]
# Out:
# {}

# %%
>>> FG=nx.Graph()
>>> FG.add_weighted_edges_from([(1,2,0.125),(1,3,0.75),(2,4,1.2),(3,4,0.375)])
>>> for n,nbrs in FG.adjacency():
...    for nbr,eattr in nbrs.items():
...        data=eattr['weight']
...        if data<0.5: print('(%d, %d, %.3f)' % (n,nbr,data))
# Out:
# (1, 2, 0.125)
# (2, 1, 0.125)
# (3, 4, 0.375)
# (4, 3, 0.375)

# %%
G.nodes[2]['room'] = 714

# %%
G.nodes(data=True)
# Out:
# NodeDataView({1: {}, 2: {'room': 714}, 3: {}, 'spam': {}})

# %%
G.add_edge(1, 2, foo='bar')

# %%
G.nodes(data=True)
# Out:
# NodeDataView({1: {}, 2: {'room': 714}, 3: {}, 'spam': {}})

# %%
>>> H = nx.Graph(DG) # convert G to undirected graph

# %%
H

# %%
DG

# %%
>>> import matplotlib.pyplot as plt
>>> nx.draw(G)

# %%
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout


G = nx.DiGraph()
G.add_node(1,level=1)
G.add_node(2,level=2)
G.add_node(3,level=2)
G.add_node(4,level=3)

G.add_edge(1,2)
G.add_edge(1,3)
G.add_edge(2,4)

nx.draw(G, pos=graphviz_layout(G), node_size=1600, cmap=plt.cm.autumn,
        node_color=range(len(G)),
        prog='acyclic')

# %% [markdown]
# <h1> Create Epidemiology net

# %%
# %load_ext autoreload

# %autoreload 2
import lib.network as net

# %%
res = net.Network()
res.init_random(n=50, k=10, weighted=False)

# %%
res.avg_degree()
# Out:
# 10.0

# %%
res.draw()

# %%
import copy
res2 = copy.deepcopy(res)
res2.noising_links()

# %%
res2.draw(res.pos)

# %%
trueNet = net.get_random(n=20, k=10)

# %%
trueNet.change_state(9, 'I')
trueNet.draw()

# %%
trueNet.change_state(2, 'Is')
trueNet.draw()

# %%
knowNet = net.get_dual(trueNet, z_add=5, z_rem=5)

# %%
knowNet.draw(trueNet.pos)

# %%
list(knowNet.neighbors(8))
# Out:
# [9, 3, 12, 11, 7, 1, 13, 2, 19, 14, 10, 15, 17]

# %%
knowNet.change_traced_state_fast_update(9)
# Out:
# Counter({'S': 12, 'T': 1, 'I': 0})
# Counter({'S': 16, 'T': 1, 'I': 0})
# Counter({'S': 10, 'T': 2, 'I': 0, 'Is': 0})
# Counter({'S': 11, 'T': 2, 'I': 0, 'Is': 0})
# Counter({'S': 9, 'T': 1, 'I': 0})
# Counter({'S': 5, 'T': 1, 'I': 0})
# Counter({'S': 5, 'T': 1, 'I': 0})
# Counter({'S': 6, 'T': 2, 'Is': 0, 'I': 0})
# Counter({'S': 11, 'T': 2, 'Is': 0, 'I': 0})
# Counter({'S': 12, 'T': 1, 'I': 0})
# Counter({'S': 10, 'T': 2, 'I': 0, 'Is': 0})

# %%
knowNet.node_counts[8]
# Out:
# Counter({'I': 0, 'S': 11, 'Is': 0, 'T': 2})

# %% [markdown]
# <h1> Running experiments

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import run
import lib.stats as stat
import lib.utils as utils
import lib.network as net
import lib.simulation as sim

# %%
import importlib
importlib.reload(run)
# Out:
# <module 'run' from 'D:\\OneDrive - University of Southampton\\PhD\\Contact\\run.py'>

# %%
st = run.run_mock(netsize=20, multip=False, model='covid', dual=True, nnets=1, niters=1, nevents=0, 
                  separate_traced=True, tautrange=False, seed=35, taut=0.3, draw=True)

# %%
# Dictionary of full summaries for all experiments (across overlaps and tracing rates)
try:
    sts = utils.get_pkl('sts')
except:
    sts = {}

# %%
sts[1]['args']
# Out:
# {'beta': 0.1,
#  'alpha': 0.27027027027027023,
#  'gamma': 0.2631578947368421,
#  'taur': 0.1,
#  'taut': 0.1,
#  'tautrange': True,
#  'gammatau': 0.5,
#  'netsize': 1000,
#  'k': 10,
#  'draw': False,
#  'dual': False,
#  'overlap': 0.08,
#  'zadd': 5,
#  'zrem': 5,
#  'nnets': 15,
#  'niters': 30,
#  'nevents': 0,
#  'seed': 35,
#  'multip': True,
#  'exposed': False,
#  'spontan': False,
#  'r0': 0.38000000000000006,
#  'true-overlap': 1}

# %%
# Run full network
print('=== Run Full Net ===')
st = run.run_mock(netsize=1000, multip=True, dual=False, nnets=15, niters=30, nevents=0, tautrange=True, seed=35)
utils.pkl(st)
sts[1] = st.full_summary()
utils.pkl(sts)
# Out:
# === Run Full Net ===
# For taut = 0
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:42<00:00,  1.42s/it]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.23s/it]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:35<00:00,  1.19s/it]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:34<00:00,  1.16s/it]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:35<00:00,  1.19s/it]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:37<00:00,  1.25s/it]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:38<00:00,  1.30s/it]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:37<00:00,  1.26s/it]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:38<00:00,  1.30s/it]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.20s/it]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:37<00:00,  1.26s/it]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:38<00:00,  1.30s/it]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:32<00:00,  1.09s/it]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:35<00:00,  1.17s/it]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:35<00:00,  1.20s/it]
# For taut = 0.1
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:34<00:00,  1.16s/it]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.22s/it]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.15it/s]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:27<00:00,  1.07it/s]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:34<00:00,  1.16s/it]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:35<00:00,  1.19s/it]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.23s/it]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.23s/it]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.22s/it]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.21s/it]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.22s/it]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:37<00:00,  1.24s/it]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:35<00:00,  1.17s/it]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:35<00:00,  1.19s/it]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:31<00:00,  1.05s/it]
# For taut = 0.25
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:32<00:00,  1.09s/it]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:25<00:00,  1.18it/s]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:36<00:00,  1.21s/it]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:31<00:00,  1.06s/it]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:34<00:00,  1.15s/it]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:32<00:00,  1.07s/it]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:32<00:00,  1.10s/it]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:33<00:00,  1.12s/it]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:34<00:00,  1.15s/it]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:32<00:00,  1.09s/it]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:30<00:00,  1.01s/it]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:28<00:00,  1.07it/s]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:30<00:00,  1.00s/it]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:32<00:00,  1.07s/it]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:31<00:00,  1.06s/it]
# For taut = 0.5
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:25<00:00,  1.17it/s]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:28<00:00,  1.04it/s]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:28<00:00,  1.06it/s]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.30it/s]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:28<00:00,  1.06it/s]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:29<00:00,  1.03it/s]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:28<00:00,  1.07it/s]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:29<00:00,  1.03it/s]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.14it/s]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.26it/s]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:29<00:00,  1.01it/s]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:24<00:00,  1.24it/s]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:30<00:00,  1.01s/it]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:27<00:00,  1.10it/s]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:28<00:00,  1.04it/s]
# For taut = 0.75
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.27it/s]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:28<00:00,  1.04it/s]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.15it/s]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.12it/s]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:25<00:00,  1.19it/s]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.26it/s]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:24<00:00,  1.24it/s]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.15it/s]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.14it/s]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.14it/s]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:26<00:00,  1.12it/s]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:22<00:00,  1.34it/s]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.25it/s]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:25<00:00,  1.20it/s]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:27<00:00,  1.09it/s]
# For taut = 1
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.30it/s]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:21<00:00,  1.38it/s]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:21<00:00,  1.37it/s]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:25<00:00,  1.20it/s]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:22<00:00,  1.35it/s]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.30it/s]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.29it/s]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:25<00:00,  1.18it/s]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:18<00:00,  1.62it/s]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:18<00:00,  1.66it/s]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:25<00:00,  1.19it/s]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:24<00:00,  1.24it/s]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:23<00:00,  1.30it/s]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:22<00:00,  1.34it/s]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:24<00:00,  1.22it/s]
# For taut = 1.5
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:17<00:00,  1.72it/s]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:13<00:00,  2.28it/s]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:21<00:00,  1.39it/s]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:19<00:00,  1.50it/s]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:16<00:00,  1.77it/s]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:20<00:00,  1.48it/s]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:15<00:00,  1.93it/s]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:16<00:00,  1.85it/s]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:17<00:00,  1.71it/s]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:17<00:00,  1.76it/s]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:12<00:00,  2.39it/s]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:18<00:00,  1.62it/s]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:14<00:00,  2.06it/s]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:16<00:00,  1.78it/s]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:16<00:00,  1.78it/s]
# For taut = 2.5
# Simulating network - No. 0
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:08<00:00,  3.61it/s]
# Simulating network - No. 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  3.87it/s]
# Simulating network - No. 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:11<00:00,  2.62it/s]
# Simulating network - No. 3
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:08<00:00,  3.59it/s]
# Simulating network - No. 4
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  3.90it/s]
# Simulating network - No. 5
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  3.97it/s]
# Simulating network - No. 6
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:09<00:00,  3.32it/s]
# Simulating network - No. 7
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  4.01it/s]
# Simulating network - No. 8
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:09<00:00,  3.28it/s]
# Simulating network - No. 9
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:09<00:00,  3.30it/s]
# Simulating network - No. 10
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  3.95it/s]
# Simulating network - No. 11
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  4.27it/s]
# Simulating network - No. 12
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  4.18it/s]
# Simulating network - No. 13
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  4.19it/s]
# Simulating network - No. 14
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [00:09<00:00,  3.17it/s]

# %%
# Run for overlaps
overlaps = [0, .08, .29, .53, .73, .85]

for overlap in overlaps:
    print('=== OVERLAP -', overlap, '===')
    st = run.run_mock(netsize=1000, multip=True, dual=True, overlap=overlap, nnets=15, niters=30, nevents=0, tautrange=True, seed=35)
    utils.pkl(st, 'st' + str(overlap))
    sts[overlap] = st.full_summary()
utils.pkl(sts)

# %%
import importlib
importlib.reload(run)
st = run.run_mock(netsize=20, multip=False, dual=False, nnets=1, niters=1, nevents=0, tautrange=False, taut=0, seed=35, draw=True)
# Out:
# For taut = 0
# Simulating network - No. 0
# Running iteration 0:
#   0%|                                                                                         | 0/1 [00:00<?, ?it/s]
# ---> Result:20 total infected persons over time.
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.05it/s]

# %%
overlaps = [0, .08, .29, .53, .73, .85]
for overlap in overlaps:
    stik = utils.get_pkl('st'+str(overlap))
    sts[overlap] = stik.full_summary()

# %%
sts[0.08][.5]['average-max-infected']
# Out:
# 238.2

# %%
stik[.5][5][29][-1].time
# Out:
# 59.989296658971035

# %% [markdown]
# <h1> Replotting everything

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(14, 8))
ax[0].set_title('$\Gamma$ = 1')
ax[1].set_title('$\Gamma$ = 0.08')
ax[0].set_ylim(1, 1000)
ax[1].set_ylim(1, 1000)
ax[0].set_xlabel('time')
ax[1].set_xlabel('time')
ax[0].set_ylabel('average-infected')
ax[1].set_ylabel('average-infected')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
to_plot = sts[1][0]['average-infected']
to_plot[to_plot < 1] = 1
ax[0].plot(sts[1][0]['time'], to_plot, label=0)
ax[1].plot(sts[1][0]['time'], to_plot, label=r'$\tau_t=0$')
for taut in sts[0]:
    if taut == .75:
        continue
    try:
        to_plot = sts[1][taut]['average-infected']
#         to_plot[to_plot < 1] = 1
        ax[0].set_xlim(0, 120)
        ax[0].plot(sts[1][taut]['time'], to_plot, label=r'$\tau_t=$'+str(taut))
        ax[1].set_xlim(0, 120)
        to_plot = sts[.08][taut]['average-infected']
#         to_plot[to_plot < 1] = 1
        ax[1].plot(sts[.08][taut]['time'], to_plot, label=r'$\tau_t=$'+str(taut))
    except:
        pass
plt.legend()
plt.savefig('fig/avg-infected-overlap-1and.08-with-time.png')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(14, 8))
ax[0].set_title('$\Gamma$ = 1')
ax[1].set_title('$\Gamma$ = 0.08')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].set_xlabel('random-time-unit')
ax[1].set_xlabel('random-time-unit')
ax[0].set_ylabel('average-infected')
ax[1].set_ylabel('average-infected')
to_plot = sts[1][0]['average-infected']
to_plot[to_plot < 1] = 1
ax[0].plot(to_plot, label=0)
ax[1].plot(to_plot, label=0)
for taut in sts[0]:
    if taut == .75:
        continue
    try:
        to_plot = sts[1][taut]['average-infected']
        to_plot[to_plot < 1] = 1
        ax[0].set_xlim(0, 600)
        ax[0].plot(to_plot, label=taut)
        ax[1].set_xlim(0, 600)
        to_plot = sts[.08][taut]['average-infected']
        to_plot[to_plot < 1] = 1
        ax[1].plot(to_plot, label=taut)
    except:
        pass
plt.legend()
plt.savefig('fig/avg-infected-overlap-1and.08.png')

# %%
utils.get_z_for_overlap(10, .08)
# Out:
# 8.518518518518519

# %%
import matplotlib.pyplot as plt
overlaps = sorted(sts.keys())

fig, ax = plt.subplots(1, 2, figsize=(14, 8))
ax[0].set_title('Max infected')
ax[1].set_title('Time of Max')
ax[0].set_yscale('log')
ax[0].set_xlabel('overlap')
ax[0].set_ylabel('average-max-infected')
to_plot = sts[1][0]['average-max-infected']
# to_plot[to_plot < 1] = 1
ax[1].set_xlabel('overlap')
ax[1].set_ylabel('time-of-max-infected')
ax[0].plot(overlaps, [sts[1][0]['average-max-infected']] * len(overlaps), label=0)
ax[1].plot(overlaps, [sts[1][0]['average-time-of-max-infected']] * len(overlaps), label=r'$\tau_t=0$')

for taut in sts[0]:
    if type(taut) == str:
        continue
    to_plot = []
    to_plot_time = []
    for overlap in overlaps:
        try:
            to_plot.append(sts[overlap][taut]['average-max-infected'])
            to_plot_time.append(sts[overlap][taut]['average-time-of-max-infected'])
        except:
            print('da')
    ax[0].plot(overlaps, to_plot, label=r'$\tau_t=$'+str(taut))
    ax[1].plot(overlaps, to_plot_time, label=r'$\tau_t=$'+str(taut))
plt.legend()
plt.savefig('fig/max-infected-and-time')

# %%
import matplotlib.pyplot as plt
overlaps = sorted(sts.keys())

fig, ax = plt.subplots(1, 2, figsize=(14, 8))
# ax[0].set_yscale('log')
to_plot = sts[1][0]['average-max-infected']
# to_plot[to_plot < 1] = 1
ax[0].plot(overlaps, [1] * len(overlaps), label=0)
ax[1].plot(overlaps, [sts[1][0]['average-time-of-max-infected']] * len(overlaps), label=r'$\tau_t=0$')

for taut in sts[0]:
    if type(taut) == str:
        continue
    to_plot = []
    to_plot_time = []
    for overlap in overlaps:
        try:
            to_plot.append(- sts[overlap][taut]['average-max-infected'] + sts[1][0]['average-max-infected'])
            to_plot_time.append(sts[overlap][taut]['average-time-of-max-infected'])
        except:
            pass
    ax[0].plot(overlaps, to_plot, label=r'$\tau_t=$'+str(taut))
#     ax[1].set_title('Time to max')
    ax[1].plot(overlaps, to_plot_time, label=r'$\tau_t=$'+str(taut))
ax[0].set_title('Peak Surpression')
ax[1].set_title('Time of Max')
plt.legend()
plt.savefig('fig/peak-surpression-and-time')

# %%
import matplotlib.pyplot as plt
overlaps = sorted(sts.keys())

fig, ax = plt.subplots(4, 2, figsize=(14, 20))
ax[0][0].set_yscale('log')
ax[0][0].set_title('Tracing rate=' + str(0))
ax[0][0].set_xlim(0, 120)
ax[0][0].plot(sts[1][0]['time'], sts[1][0]['average-infected'], label=r'$\tau_t=0$')
ax[0][0].set_ylabel('average-infected')
ax[0][0].set_ylim(1, 1000)


for k, taut in enumerate(sts[0]):
    if type(taut) == str:
        continue
    i = k // 2
    j = k % 2
    ax[i][j].set_ylim(1, 1000)
    ax[i][j].set_xlabel('time')
    ax[i][j].set_ylabel('average-infected')
    ax[i][j].set_xlim(0,120)
    ax[i][j].set_yscale('log')
    ax[i][j].plot(sts[1][0]['time'], sts[1][0]['average-infected'], label=r'$\tau_t=0$')
    ax[i][j].set_title('Tracing rate=' + str(taut))
    for overlap in overlaps:
        to_plot = sts[overlap][taut]['average-infected']
#         to_plot[to_plot<1] = 1
        ax[i][j].plot(sts[overlap][taut]['time'], to_plot, label='\u0393='+str(overlap))
        
plt.legend()
plt.savefig('fig/overlap-avg-infected-foreach-taut')

# %%
import matplotlib.pyplot as plt
overlaps = sorted(sts.keys())

fig, ax = plt.subplots(4, 2, figsize=(14, 16))
ax[0][0].set_title('Tracing rate=' + str(0))
ax[0][0].set_yscale('log')
ax[0][0].set_title(0)
ax[0][0].set_xlim(0, 500)
ax[0][0].plot(sts[1][0]['average-infected'], label='rate0')

for k, taut in enumerate(sts[0]):
    if type(taut) == str:
        continue
    i = k // 2
    j = k % 2
    ax[i][j].set_xlim(0,500)
    ax[i][j].set_yscale('log')
    ax[i][j].plot(sts[1][0]['average-infected'], label='rate0')
    ax[i][j].set_title('Tracing rate=' + str(taut))
    for overlap in overlaps:
        to_plot = sts[overlap][taut]['average-infected']
        to_plot[to_plot<1] = 1
        ax[i][j].plot(to_plot, label=overlap)
        
plt.legend()

# %% [markdown]
# <h1> Profiling

# %%
importlib.reload(sim)
# Out:
# <module 'lib.simulation' from 'D:\\OneDrive - University of Southampton\\PhD\\Contact\\lib\\simulation.py'>

# %%
st[0][.001][0][1][1]
# Out:
# {'nI': 0,
#  'nE': 0,
#  'nH': 0,
#  'totalInfected': 1,
#  'totalInfectious': 1,
#  'totalTraced': 0,
#  'totalFalseTraced': 0,
#  'totalRecovered': 1,
#  'totalHospital': 0,
#  'totalDeath': 0,
#  'tracingEffortRandom': 9.99,
#  'tracingEffortContact': 0.0,
#  'time': 0.9430033489783827}

# %%
importlib.reload(net)
# Out:
# <module 'lib.network' from 'D:\\OneDrive - University of Southampton\\PhD\\Contact\\lib\\network.py'>

# %%
import lib.utils as utils
import run
import importlib
import lib.network as net
import lib.exp_sampler as samp
import lib.simulation as sim
utils.rel(sim, net, utils, samp, net, run)
profiler = utils.Profiler()
with profiler():
    run.run_mock(netsize=1000, k=10, isolate_s=True, trace_once=False, first_inf=.1, presample=20000, nettype='ws', \
                                p=.03, seed=2, rem_orphans=True, taut=.01, taut_two=.05, model='covid', netseed=13, \
                                multip=0, nnets=2, niters=1, dual=1, taur=0.1, noncomp=.001, overlap_two=.7, noncomp_after=14, 
                                uptake=.5, maintain_overlap=False, separate_traced=True, efforts=False,
                                draw=False, draw_iter=False, draw_layout='spring', sampling_type='min',
                                summary_print=-1, summary_splits=100, r_window=7, avg_without_earlystop=True)
profiler.stat()
# Out:
# =========================================================
# Running simulation with parameters:
# netsize = 1000, k = 10, dual = 1, model = covid
# overlap = 0.8, uptake = 0.5, maintain_overlap = False
# taut = 0.01, taur = 0.1, noncomp = 0.001, noncomp_time = True
# =========================================================
#
# ----- Simulating network no. 0 -----
# Running iteration 0:
# ---> Result:555 total infected persons over time.
# Iterations simulation progress: 100%|████████████████████████████████████████████████████| 1/1 [00:18<00:00, 18.50s/it]
# ----- Simulating network no. 1 -----
# Running iteration 0:
# ---> Result:596 total infected persons over time.
# Iterations simulation progress: 100%|████████████████████████████████████████████████████| 1/1 [00:19<00:00, 19.16s/it]
#          40534661 function calls (40430009 primitive calls) in 34.102 seconds
#
#    Ordered by: cumulative time, internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   38.131   38.131 run.py:215(run_mock)
#         1    0.002    0.002   38.131   38.131 run.py:75(main)
#         2    0.000    0.000   38.113   19.056 multirun_engine.py:34(__call__)
#         2    1.520    0.760   37.639   18.820 multirun_engine.py:135(__call__)
#      5806   12.345    0.002   35.687    0.006 simulation.py:153(get_next_event_sample_only_minimum)
#   3910212    3.495    0.000   10.145    0.000 utils.py:82(<lambda>)
#   3910212    6.359    0.000    6.651    0.000 utils.py:126(expFactorTimesCountImportance_rate)
#   3401031    5.660    0.000    5.978    0.000 utils.py:151(expFactorTimesCountMultiState_rate)
#  18270454    1.776    0.000    1.776    0.000 {method 'append' of 'list' objects}
#     10847    0.999    0.000    0.999    0.000 {built-in method numpy.array}
#   8155350    0.610    0.000    0.610    0.000 __init__.py:570(__missing__)
#         2    0.002    0.001    0.332    0.166 network.py:407(get_dual)
#   86640/2    0.108    0.000    0.262    0.131 copy.py:132(deepcopy)
#    2006/2    0.014    0.000    0.262    0.131 copy.py:269(_reconstruct)
#   16012/2    0.055    0.000    0.262    0.131 copy.py:237(_deepcopy_dict)
#      5036    0.032    0.000    0.214    0.000 simulation.py:244(run_event_no_update)
#      5038    0.059    0.000    0.199    0.000 network.py:244(change_state)
#   1702799    0.168    0.000    0.168    0.000 utils.py:75(<lambda>)
#      5039    0.017    0.000    0.119    0.000 <__array_function__ internals>:2(atleast_1d)
#    103742    0.102    0.000    0.102    0.000 utils.py:110(expFactorTimesTimeDif_rate)
#      5041    0.011    0.000    0.100    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      5036    0.034    0.000    0.095    0.000 simulation.py:240(run_event)
#         2    0.004    0.002    0.093    0.046 network.py:390(get_random)
#      5806    0.089    0.000    0.089    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#      5039    0.032    0.000    0.089    0.000 shape_base.py:24(atleast_1d)
#         2    0.000    0.000    0.080    0.040 network.py:59(init_random)
#         2    0.001    0.001    0.068    0.034 network.py:89(noising_links)
#    116120    0.060    0.000    0.060    0.000 {built-in method builtins.setattr}
#        14    0.047    0.003    0.057    0.004 graph.py:884(add_edges_from)
#      5036    0.047    0.000    0.057    0.000 network.py:253(change_state_fast_update)
#      5806    0.017    0.000    0.051    0.000 simulation.py:25(<lambda>)
#      5806    0.017    0.000    0.047    0.000 utils.py:378(__init__)
#         2    0.004    0.002    0.044    0.022 network.py:70(<lambda>)
#         4    0.008    0.002    0.039    0.010 network.py:189(update_counts)
#      6000    0.014    0.000    0.037    0.000 __init__.py:550(__init__)
#      5806    0.024    0.000    0.035    0.000 exp_sampler.py:31(get_next_sample)
#         2    0.000    0.000    0.031    0.016 <decorator-gen-731>:1(watts_strogatz_graph)
#         2    0.000    0.000    0.031    0.016 decorators.py:453(_random_state)
#         2    0.002    0.001    0.031    0.016 random_graphs.py:363(watts_strogatz_graph)
#         2    0.000    0.000    0.031    0.015 network.py:318(add_links)
#     88921    0.029    0.000    0.029    0.000 utils.py:381(__getattr__)
#      5041    0.004    0.000    0.029    0.000 _asarray.py:86(asanyarray)
#      5821    0.010    0.000    0.029    0.000 {built-in method builtins.next}
#    185649    0.028    0.000    0.028    0.000 {method 'get' of 'dict' objects}
#        33    0.000    0.000    0.027    0.001 iostream.py:337(flush)
#      1540    0.007    0.000    0.027    0.000 simulation.py:248(run_trace_event)
#      4012    0.001    0.000    0.026    0.000 copy.py:274(<genexpr>)
#      2708    0.020    0.000    0.025    0.000 network.py:274(change_traced_state_fast_update)
#        33    0.000    0.000    0.025    0.001 threading.py:534(wait)
#        33    0.000    0.000    0.024    0.001 threading.py:264(wait)
#       348    0.024    0.000    0.024    0.000 {method 'acquire' of '_thread.lock' objects}
#      5037    0.024    0.000    0.024    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      6000    0.009    0.000    0.022    0.000 __init__.py:619(update)
#        52    0.000    0.000    0.021    0.000 utils.py:221(inner)
#         4    0.000    0.000    0.018    0.005 utils.py:231(tqdm_print)
#         4    0.000    0.000    0.018    0.005 std.py:614(write)
#         8    0.000    0.000    0.018    0.002 std.py:623(external_write_mode)
#      9708    0.014    0.000    0.017    0.000 graph.py:1199(neighbors)
#         2    0.005    0.003    0.017    0.009 network.py:134(<setcomp>)
#     18024    0.012    0.000    0.017    0.000 copy.py:253(_keep_alive)
#      5806    0.017    0.000    0.017    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.016    0.005 utils.py:283(pvar)
#         6    0.003    0.000    0.014    0.002 copy.py:211(_deepcopy_list)
#     20004    0.014    0.000    0.014    0.000 reportviews.py:1116(__iter__)
#        14    0.000    0.000    0.014    0.001 std.py:334(print_status)
#         2    0.005    0.003    0.013    0.007 network.py:96(<setcomp>)
#        19    0.000    0.000    0.013    0.001 {built-in method builtins.print}
#        14    0.000    0.000    0.013    0.001 std.py:328(fp_write)
#         2    0.013    0.006    0.013    0.006 graph.py:1008(remove_edges_from)
#         6    0.000    0.000    0.013    0.002 contextlib.py:107(__enter__)
#         4    0.000    0.000    0.012    0.003 std.py:1348(clear)
#    122694    0.011    0.000    0.011    0.000 {built-in method builtins.id}
#        10    0.000    0.000    0.011    0.001 std.py:1495(display)
#      7478    0.008    0.000    0.010    0.000 reportviews.py:772(__iter__)
#         8    0.000    0.000    0.010    0.001 std.py:1364(refresh)
#      8235    0.004    0.000    0.010    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.008    0.002 utils.py:244(tqdm_redirect)
#     44325    0.008    0.000    0.008    0.000 {method 'update' of 'dict' objects}
#         8    0.000    0.000    0.008    0.001 std.py:1472(moveto)
#       183    0.001    0.000    0.007    0.000 iostream.py:197(schedule)
#        81    0.001    0.000    0.007    0.000 iostream.py:386(write)
#     15806    0.006    0.000    0.006    0.000 {method 'random' of '_random.Random' objects}
#     58616    0.006    0.000    0.006    0.000 copy.py:190(_deepcopy_atomic)
#       183    0.006    0.000    0.006    0.000 socket.py:432(send)
#     43413    0.006    0.000    0.006    0.000 {built-in method builtins.len}
#         7    0.000    0.000    0.006    0.001 contextlib.py:116(__exit__)
#      6009    0.002    0.000    0.005    0.000 abc.py:137(__instancecheck__)
#         2    0.000    0.000    0.005    0.002 network.py:181(add_mult)
#         2    0.004    0.002    0.005    0.002 graph.py:513(add_nodes_from)
#      4000    0.005    0.000    0.005    0.000 network.py:198(<listcomp>)
#      2004    0.002    0.000    0.005    0.000 graph.py:1365(degree)
#     17476    0.005    0.000    0.005    0.000 {built-in method builtins.sorted}
#         4    0.000    0.000    0.004    0.001 std.py:1140(__iter__)
#      2004    0.002    0.000    0.004    0.000 reportviews.py:351(__call__)
#      2006    0.002    0.000    0.004    0.000 {method '__reduce_ex__' of 'object' objects}
#         4    0.000    0.000    0.004    0.001 network.py:33(get_simulator)
#         4    0.000    0.000    0.004    0.001 simulation.py:13(__init__)
#         4    0.000    0.000    0.004    0.001 exp_sampler.py:41(get_sampler)
#         4    0.000    0.000    0.004    0.001 exp_sampler.py:26(__init__)
#         2    0.000    0.000    0.004    0.002 std.py:832(__init__)
#         4    0.004    0.001    0.004    0.001 {method 'exponential' of 'numpy.random.mtrand.RandomState' objects}
#      9714    0.003    0.000    0.003    0.000 {built-in method builtins.iter}
#      6009    0.003    0.000    0.003    0.000 {built-in method _abc._abc_instancecheck}
#      2004    0.002    0.000    0.003    0.000 reportviews.py:344(__init__)
#         3    0.000    0.000    0.003    0.001 inspect.py:1444(getframeinfo)
#         2    0.000    0.000    0.003    0.001 network.py:330(avg_degree)
#      4000    0.003    0.000    0.003    0.000 {built-in method _collections._count_elements}
#      2002    0.002    0.000    0.003    0.000 reportviews.py:445(__getitem__)
#         9    0.002    0.000    0.002    0.000 {built-in method nt.stat}
#        36    0.000    0.000    0.002    0.000 {built-in method builtins.sum}
#         3    0.000    0.000    0.002    0.001 std.py:1308(close)
#         6    0.000    0.000    0.002    0.000 inspect.py:680(getsourcefile)
#      2000    0.002    0.000    0.002    0.000 __init__.py:697(__reduce__)
#         6    0.000    0.000    0.002    0.000 genericpath.py:16(exists)
#     17018    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#         3    0.001    0.000    0.002    0.001 random.py:286(sample)
#        10    0.000    0.000    0.002    0.000 std.py:1130(__repr__)
#         3    0.000    0.000    0.002    0.001 inspect.py:760(findsource)
#      5039    0.002    0.000    0.002    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#        10    0.000    0.000    0.002    0.000 std.py:341(format_meter)
#      2002    0.002    0.000    0.002    0.000 reportviews.py:454(__iter__)
#      7476    0.002    0.000    0.002    0.000 reportviews.py:703(<lambda>)
#        34    0.000    0.000    0.002    0.000 utils.py:405(disp_len)
#        34    0.000    0.000    0.001    0.000 utils.py:400(_text_width)
#      1405    0.001    0.000    0.001    0.000 random.py:224(_randbelow)
#         2    0.001    0.001    0.001    0.001 utils.py:318(_screen_shape_windows)
#      3036    0.001    0.000    0.001    0.000 utils.py:402(<genexpr>)
#         2    0.000    0.000    0.001    0.000 reportviews.py:1112(__len__)
#        81    0.000    0.000    0.001    0.000 iostream.py:323(_schedule_flush)
#      4042    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      4066    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      2002    0.001    0.000    0.001    0.000 reportviews.py:1113(<genexpr>)
#       216    0.000    0.000    0.001    0.000 threading.py:1092(is_alive)
#        33    0.000    0.000    0.001    0.000 threading.py:499(__init__)
#       303    0.001    0.000    0.001    0.000 graph.py:820(add_edge)
#         2    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(mean)
#        10    0.000    0.000    0.001    0.000 utils.py:413(disp_trim)
#         2    0.000    0.000    0.001    0.000 fromnumeric.py:3269(mean)
#         2    0.000    0.000    0.001    0.000 _methods.py:143(_mean)
#       305    0.000    0.000    0.000    0.000 random.py:256(choice)
#         3    0.000    0.000    0.000    0.000 compilerop.py:153(check_linecache_ipython)
#         3    0.000    0.000    0.000    0.000 linecache.py:53(checkcache)
#         4    0.000    0.000    0.000    0.000 std.py:1325(fp_write)
#      3002    0.000    0.000    0.000    0.000 {built-in method unicodedata.east_asian_width}
#         2    0.000    0.000    0.000    0.000 reportviews.py:1019(__call__)
#        33    0.000    0.000    0.000    0.000 threading.py:216(__init__)
#         2    0.000    0.000    0.000    0.000 reportviews.py:687(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         2    0.000    0.000    0.000    0.000 reportviews.py:695(<lambda>)
#         2    0.000    0.000    0.000    0.000 reportviews.py:695(<listcomp>)
#       216    0.000    0.000    0.000    0.000 threading.py:1050(_wait_for_tstate_lock)
#      1837    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#      2008    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        73    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        66    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        81    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       303    0.000    0.000    0.000    0.000 graph.py:975(remove_edge)
#      1002    0.000    0.000    0.000    0.000 graph.py:1894(bunch_iter)
#       183    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 inspect.py:714(getmodule)
#         7    0.000    0.000    0.000    0.000 random.py:97(seed)
#        33    0.000    0.000    0.000    0.000 threading.py:252(_acquire_restore)
#        14    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         3    0.000    0.000    0.000    0.000 inspect.py:702(getabsfile)
#         2    0.000    0.000    0.000    0.000 std.py:555(__new__)
#        16    0.000    0.000    0.000    0.000 std.py:107(release)
#        14    0.000    0.000    0.000    0.000 std.py:258(format_interval)
#        16    0.000    0.000    0.000    0.000 std.py:103(acquire)
#      1405    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         2    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#         5    0.000    0.000    0.000    0.000 random.py:88(__init__)
#         3    0.000    0.000    0.000    0.000 ntpath.py:523(abspath)
#         6    0.000    0.000    0.000    0.000 inspect.py:642(getfile)
#         2    0.000    0.000    0.000    0.000 std.py:584(_decr_instances)
#        10    0.000    0.000    0.000    0.000 std.py:1477(format_dict)
#         2    0.000    0.000    0.000    0.000 misc.py:378(create_py_random_state)
#        20    0.000    0.000    0.000    0.000 utils.py:294(_is_ascii)
#        34    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       305    0.000    0.000    0.000    0.000 graph.py:1158(has_edge)
#         8    0.000    0.000    0.000    0.000 std.py:111(__enter__)
#         3    0.000    0.000    0.000    0.000 ntpath.py:450(normpath)
#         6    0.000    0.000    0.000    0.000 graph.py:1242(edges)
#        33    0.000    0.000    0.000    0.000 threading.py:243(__exit__)
#         6    0.000    0.000    0.000    0.000 contextlib.py:237(helper)
#         2    0.000    0.000    0.000    0.000 utils.py:36(get_overlap_for_z)
#        10    0.000    0.000    0.000    0.000 std.py:188(__format__)
#        81    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 simulation.py:179(<dictcomp>)
#         7    0.000    0.000    0.000    0.000 {function Random.seed at 0x000001BF45DE5558}
#        33    0.000    0.000    0.000    0.000 threading.py:240(__enter__)
#       218    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#        33    0.000    0.000    0.000    0.000 threading.py:255(_is_owned)
#         2    0.000    0.000    0.000    0.000 std.py:577(_get_free_pos)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         8    0.000    0.000    0.000    0.000 std.py:114(__exit__)
#         6    0.000    0.000    0.000    0.000 reportviews.py:992(__init__)
#         6    0.000    0.000    0.000    0.000 contextlib.py:81(__init__)
#        16    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#        33    0.000    0.000    0.000    0.000 threading.py:249(_release_save)
#       216    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 network.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 _methods.py:59(_count_reduce_items)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         1    0.000    0.000    0.000    0.000 models.py:8(get_transitions_for_model)
#        16    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#        10    0.000    0.000    0.000    0.000 std.py:155(__init__)
#         2    0.000    0.000    0.000    0.000 std.py:580(<genexpr>)
#         2    0.000    0.000    0.000    0.000 utils.py:234(__init__)
#         1    0.000    0.000    0.000    0.000 models.py:60(covid)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#        12    0.000    0.000    0.000    0.000 utils.py:243(__eq__)
#         4    0.000    0.000    0.000    0.000 graph.py:290(__init__)
#         2    0.000    0.000    0.000    0.000 utils.py:287(_supports_unicode)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#        17    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 inspect.py:687(<genexpr>)
#        10    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        12    0.000    0.000    0.000    0.000 inspect.py:63(ismodule)
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         8    0.000    0.000    0.000    0.000 utils.py:390(_term_move_up)
#       210    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#        33    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 copyreg.py:96(_slotnames)
#         6    0.000    0.000    0.000    0.000 re.py:273(_compile)
#         3    0.000    0.000    0.000    0.000 re.py:182(search)
#         3    0.000    0.000    0.000    0.000 ntpath.py:122(splitdrive)
#         2    0.000    0.000    0.000    0.000 graph.py:1848(nbunch_iter)
#        15    0.000    0.000    0.000    0.000 models.py:93(add_trans)
#         3    0.000    0.000    0.000    0.000 inspect.py:1507(currentframe)
#         2    0.000    0.000    0.000    0.000 graph.py:388(__iter__)
#         1    0.000    0.000    0.000    0.000 std.py:1127(__del__)
#        24    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 numeric.py:1816(isscalar)
#         3    0.000    0.000    0.000    0.000 re.py:234(compile)
#        33    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         3    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        18    0.000    0.000    0.000    0.000 inspect.py:690(<genexpr>)
#        12    0.000    0.000    0.000    0.000 inspect.py:228(istraceback)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#        33    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         9    0.000    0.000    0.000    0.000 inspect.py:80(ismethod)
#         3    0.000    0.000    0.000    0.000 multirun_engine.py:19(__init__)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         4    0.000    0.000    0.000    0.000 utils.py:227(redirect_to_tqdm)
#         3    0.000    0.000    0.000    0.000 <string>:1(__new__)
#        38    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         6    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#         2    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         3    0.000    0.000    0.000    0.000 ntpath.py:44(normcase)
#         2    0.000    0.000    0.000    0.000 graph.py:406(__contains__)
#        10    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        16    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        10    0.000    0.000    0.000    0.000 utils.py:137(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:399(__call__)
#         2    0.000    0.000    0.000    0.000 utils.py:154(__eq__)
#         2    0.000    0.000    0.000    0.000 utils.py:273(_is_utf)
#         6    0.000    0.000    0.000    0.000 std.py:658(get_lock)
#         3    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#         9    0.000    0.000    0.000    0.000 inspect.py:72(isclass)
#         3    0.000    0.000    0.000    0.000 {built-in method math.log}
#         4    0.000    0.000    0.000    0.000 {built-in method now}
#         9    0.000    0.000    0.000    0.000 inspect.py:158(isfunction)
#        55    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         3    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#        12    0.000    0.000    0.000    0.000 inspect.py:238(isframe)
#         9    0.000    0.000    0.000    0.000 inspect.py:252(iscode)
#        10    0.000    0.000    0.000    0.000 utils.py:141(__format__)
#         2    0.000    0.000    0.000    0.000 utils.py:185(__init__)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#        16    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         7    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFF10A7E3F0}
#         2    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         3    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         6    0.000    0.000    0.000    0.000 utils.py:181(wrapper_setattr)
#        14    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 stats.py:26(results_for_param)
#        33    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 _monitor.py:92(report)
#         4    0.000    0.000    0.000    0.000 std.py:1133(_comparable)
#         1    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#        10    0.000    0.000    0.000    0.000 std.py:169(colour)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         2    0.000    0.000    0.000    0.000 graph.py:754(number_of_nodes)
#         6    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 graph.py:420(__len__)
#         2    0.000    0.000    0.000    0.000 std.py:318(status_printer)
#         4    0.000    0.000    0.000    0.000 std.py:1137(__hash__)
#         9    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 linecache.py:37(getlines)
#         2    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 models.py:23(populate_tracing_trans)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 utils.py:168(__getattr__)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         9    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         1    0.000    0.000    0.000    0.000 stats.py:13(__init__)
#         3    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        10    0.000    0.000    0.000    0.000 std.py:165(colour)
#         3    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         2    0.000    0.000    0.000    0.000 utils.py:78(get_stateful_sampling_func)
#         8    0.000    0.000    0.000    0.000 utils.py:73(get_stateless_sampling_func)
#         4    0.000    0.000    0.000    0.000 utils.py:216(disable_on_exception)
#         2    0.000    0.000    0.000    0.000 utils.py:303(_screen_shape_wrapper)
#         2    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 argparse.py:1232(__init__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3265(_mean_dispatcher)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 std.py:299(ema)
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
import numpy as np
from timeit import timeit
size = 100000000
print(timeit(lambda: iter((tuple(np.random.exponential(1,size)))), number=1))
exp = iter((tuple(np.random.exponential(1,size))))
timeit(lambda: next(exp), number=size)
# Out:
# 23.504891399999906
# 34.027888300000086
